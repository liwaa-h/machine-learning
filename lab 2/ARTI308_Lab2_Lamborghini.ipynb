# %%
import pandas as pd

df = pd.read_csv('lamborghini_stock_data.csv')

print("Dataset Shape:", df.shape)

print("\nFirst 5 rows:")
print(df.head())

print("\nDataset Information:")
print(df.info())
# Out:
# Dataset Shape: (552, 20)
#
# First 5 rows:
#          Date  Year  Month  Open  High   Low  Close  Adj Close    Volume  \
# 0  1980-01-01  1980      1  2.56  2.60  2.51   2.58       2.59  37598928
# 1  1980-02-01  1980      2  2.31  2.32  2.29   2.31       2.32  37570403
# 2  1980-03-01  1980      3  2.53  2.55  2.47   2.51       2.50  15449461
# 3  1980-04-01  1980      4  2.37  2.41  2.30   2.35       2.36  36985658
# 4  1980-05-01  1980      5  2.38  2.43  2.34   2.37       2.36   5667767
#
#    Dividend Stock Split  PE Ratio  Market Cap ($M)  52W High  52W Low  \
# 0       0.0         NaN      14.0             97.0      2.97     2.19
# 1       0.0         NaN      21.6             86.8      2.66     1.96
# 2       0.0         NaN      34.0             38.7      2.88     2.13
# 3       0.0         NaN      14.9             86.9      2.70     2.00
# 4       0.0         NaN      13.1             13.4      2.73     2.02
#
# ...
